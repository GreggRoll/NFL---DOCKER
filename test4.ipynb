# %%
import requests
import sqlite3
from datetime import datetime, timedelta
import logging
import json
from bs4 import BeautifulSoup
import pandas as pd
import openai
from dotenv import load_dotenv
import os

# Set your OpenAI API key
load_dotenv()
client = openai.OpenAI(api_key=os.getenv('API_KEY'))

def setup_logger(name):
    """Set up a logger for a given module."""
    logger = logging.getLogger(name)
    logger.setLevel(logging.INFO)

    # Create file handler which logs even debug messages
    fh = logging.FileHandler('app.log')
    formatter = logging.Formatter('%(asctime)s [%(levelname)s] - %(message)s')
    fh.setFormatter(formatter)

    # Add the handler to the logger
    if not logger.handlers:
        logger.addHandler(fh)

    return logger

logger = setup_logger(__name__)

def insert_news(df):
    conn = sqlite3.connect('../data-log.db')
    cursor = conn.cursor()

    # Function to check if a row with the same title exists and if relevant is not None
    def row_exists_and_relevant_not_none(title):
        cursor.execute("SELECT relevant FROM espn_news WHERE title = ?", (title,))
        row = cursor.fetchone()
        return row is not None and row[0] is not None

    for ix, row in df.iterrows():
        if row_exists_and_relevant_not_none(row['title']):
            # Update the row
            cursor.execute('''
            UPDATE espn_news
            SET date = ?, link = ?, image_url = ?, relevant = ?, ai_score = ?
            WHERE title = ?
            ''', (row['date'], row['link'], row['image_url'], row['relevant'], row['ai_score'], row['title']))
        else:
            # Insert the row if it doesn't exist
            cursor.execute('''
            INSERT OR IGNORE INTO espn_news (title, date, link, image_url, relevant, ai_score)
            VALUES (?, ?, ?, ?, ?, ?)
            ''', (row['title'], row['date'], row['link'], row['image_url'], row['relevant'], row['ai_score']))

    # Commit the transaction
    conn.commit()

    # Close the connection
    conn.close()

    logger.info("INSERTED NEWS TO espn_news")


def get_espn_news():
    # URL of the page to scrape
    url = "https://www.nfl.com/news/all-news"

    # Send a GET request to the URL
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the HTML content of the page
        soup = BeautifulSoup(response.content, 'html.parser')

        # List to store the scraped data
        scraped_data = []

        # Function to extract article data
        def extract_article_data(article):
            # Extract the title
            title = article.find('h3', class_='d3-o-media-object__title').get_text(strip=True)

            # Extract the date
            date = article.find('p', class_='d3-o-media-object__date').get_text(strip=True)

            # Extract the link to the article
            link = article['href']
            full_link = f"https://www.nfl.com{link}"

            # Extract the image URL
            image_tag = article.find('picture').find('img')
            image_url = image_tag['src'] if image_tag else None

            # Append the extracted data to the list
            scraped_data.append({
                'title': title,
                'date': date,
                'link': full_link,
                'image_url': image_url
            })

        # Find all vertical article containers
        vertical_articles = soup.find_all('div', class_='d3-o-media-object--vertical')
        for article in vertical_articles:
            extract_article_data(article.find('a'))

        # Find all horizontal article containers
        horizontal_articles = soup.find_all('a', class_='d3-o-media-object--horizontal')
        for article in horizontal_articles:
            extract_article_data(article)

        df = pd.DataFrame(scraped_data)
        df['relevant'] = None
        df['ai_score'] = None
        insert_news(df)
        return df
    else:
        print(f"Failed to retrieve the page. Status code: {response.status_code}")

def get_unclassified(start_date, end_date):
    # Connect to SQLite database
    conn = sqlite3.connect('../data-log.db')
    cursor = conn.cursor()

    # Execute the query to get articles within the date range where relevant is None
    cursor.execute('''
    SELECT * FROM espn_news
    WHERE relevant IS NULL
    ''')
    # 1
    # Fetch all results
    articles = cursor.fetchall()

    # Close the connection
    conn.close()

    columns = ['title', 'date', 'link', 'image_url', 'relevant', 'ai_score']
    df = pd.DataFrame(articles, columns=columns)
    #filter on_days
    df['date'] = df['date'].apply(lambda x: pd.to_datetime(x))
    df = df[(df['date']>=start_date) & (df['date']<=end_date)]
    return df

def update_column(row_name, df):
    # Connect to SQLite database
    conn = sqlite3.connect('../data-log.db')
    cursor = conn.cursor()

    for ix, row in df.iterrows():
        cursor.execute(f'''
            UPDATE espn_news
            SET {row_name} = ?
            WHERE title = ?
            ''', (row[row_name], row['title']))
        
    # Commit the transaction
    conn.commit()

    # Close the connection
    conn.close()
    logger.info(f"UPDATED {row_name} in espn_news")

def extract_article_text(article_url):
    article_response = requests.get(article_url)
    if article_response.status_code == 200:
        article_soup = BeautifulSoup(article_response.content, 'html.parser')
        article_body = article_soup.find('div', class_='nfl-c-article__body')
        if article_body:
            paragraphs = article_body.find_all('p')
            article_text = "\n".join([p.get_text(strip=True) for p in paragraphs])
            return article_text
    return None

def check_relevance(title):

    completion = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "Reply True or False to whether the following news title is relevant to the odds of a team winning or losing'"},
        {"role": "user", "content": f"{title}"}
    ]
    )

    return completion.choices[0].message.content

def score_article(text):

    completion = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "You are an assistant that reads article texts about sports teams. Your task is to identify the team name mentioned in the article and provide a rating on how the information in the article will affect that team's upcoming game. The rating should be on a scale from 5 to -5, where 5 indicates the team is sure to win and -5 indicates the team is sure to lose."},
        {"role": "system", "content": "Example return: [{'Tampa Bay Buccaneers': 3}]"},
        {"role": "system", "content": "always return json with a list of teams and impacts"},
        {"role": "system", "content": "always reply in the following format: [{'Team': Score}]"},
        {"role": "system", "content": "If data is missing or not relevant return [{'None': Score}]"},
        {"role": "system", "content": "dictionary values should be the rating score, keys should be in the following list Baltimore Ravens, Buffalo Bills, Chicago Bears, Cincinnati Bengals, Dallas Cowboys, Denver Broncos, Detroit Lions, Green Bay Packers, Houston Texans, Indianapolis Colts, Jacksonville Jaguars, Kansas City Chiefs, Los Angeles Chargers, Miami Dolphins, Minnesota Vikings, New Orleans Saints, New York Giants, New York Jets, Philadelphia Eagles, San Francisco 49ers, Seattle Seahawks, Tampa Bay Buccaneers, Washington Commanders"}
        {"role": "user", "content": f"{text}"}
    ],
     response_format={ "type": "json_object" }
    )

    return completion.choices[0].message.content

def insert_espn_news(start_date, end_date):
    logger.info("Starting espn_news updates")
    get_espn_news()
    df = get_unclassified(start_date, end_date)
    df["relevant"] = df["title"].apply(check_relevance)
    logger.info(f"RAN check_relevance on {len(df)} rows")
    update_column('relevant', df)
    #update_rows(df)
    df = df[df['relevant']=='True']
    df['article_text'] = df['link'].apply(extract_article_text)
    df['ai_score'] = df['article_text'].apply(score_article)
    logger.info(f"RAN score_article on {len(df)} rows")
    update_column('ai_score', df)
    logger.info("Completed espn_news updates")

# %%
', '.join(['Baltimore Ravens',
'Buffalo Bills',
'Chicago Bears',
'Cincinnati Bengals',
'Dallas Cowboys',
'Denver Broncos',
'Detroit Lions',
'Green Bay Packers',
'Houston Texans',
'Indianapolis Colts',
'Jacksonville Jaguars',
'Kansas City Chiefs',
'Los Angeles Chargers',
'Miami Dolphins',
'Minnesota Vikings',
'New Orleans Saints',
'New York Giants',
'New York Jets',
'Philadelphia Eagles',
'San Francisco 49ers',
'Seattle Seahawks',
'Tampa Bay Buccaneers',
'Washington Commanders'])
# Out:
# 'Baltimore Ravens, Buffalo Bills, Chicago Bears, Cincinnati Bengals, Dallas Cowboys, Denver Broncos, Detroit Lions, Green Bay Packers, Houston Texans, Indianapolis Colts, Jacksonville Jaguars, Kansas City Chiefs, Los Angeles Chargers, Miami Dolphins, Minnesota Vikings, New Orleans Saints, New York Giants, New York Jets, Philadelphia Eagles, San Francisco 49ers, Seattle Seahawks, Tampa Bay Buccaneers, Washington Commanders'

# %%
with sqlite3.connect('data-log.db') as conn:
        cursor = conn.cursor()

        # Fetch the corresponding game data from the database by game_id
        cursor.execute("""
                    SELECT * FROM espn_news 
                    """)
columns = ['title', 'date', 'link', 'image_url', 'relevant', 'ai_score']
df = pd.DataFrame(cursor.fetchall(), columns=columns)

# %%
def get_start_end():
    today = datetime.now()
    weekday = today.weekday()  # Monday is 0 and Sunday is 6

    # Calculate the start date (Tuesday)
    if weekday >= 1:  # If today is Tuesday or after
        start_date = today - timedelta(days=(weekday - 1))
    else:  # If today is before Tuesday
        start_date = today - timedelta(days=(weekday + 6))

    # Calculate the end date (Monday)
    if weekday <= 0:  # If today is Monday
        end_date = today
    else:  # If today is after Monday
        end_date = today + timedelta(days=(7 - weekday))
    return start_date, end_date

start_date, end_date = get_start_end()

# Connect to SQLite database
with sqlite3.connect('data-log.db') as conn:
    cursor = conn.cursor()

    # Execute the query to get articles within the date range where relevant is None
    cursor.execute('''
    SELECT * FROM espn_news
    ''')
# 1
# Fetch all results
data = cursor.fetchall()

columns = ['title', 'date', 'link', 'image_url', 'relevant', 'ai_score']
df = pd.DataFrame(data, columns=columns)

# df['date'] = df['date'].apply(lambda x: pd.to_datetime(x))
# df = df[(df['date']>=start_date) & (df['date']<=end_date)]

final_results = []

df = df[df['ai_score'].notna()]
df['ai_score'] = df['ai_score'].str.replace('\n', '')
# def get_key(x):
#     try:
#         load = json.loads(x)
#         key =  list(load.keys())[0]
#         if key.lower() in ['result', 'results', 'team', 'team_name']:
#             return load[key]
#         return key
#     except:
#         return None

# def get_value(x):
#     try:
#         return list(json.loads(x).values())[0]
#     except:
#         return None
    
# """
# LOOP!
# If len keys >1 create new row!
# """

# df['team'] = df['ai_score'].apply(get_key)
# df['impact'] = df['ai_score'].apply(get_value)

# %%
items = []
for ix, row in df.iterrows():
    load = json.loads(row['ai_score'])
    keys =  list(load.keys())
    # if key.lower() in ['result', 'results', 'team', 'team_name']:
    #     return load[key]
    if len(keys)!=0:
        if keys[0].lower() in ['result', 'results', 'team', 'team_name']:
            if len(load[keys[0]]) > 1:
                try:
                    for r in load[keys[0]]:
                        item = {
                            "title": row['title'],
                            "team": list(r.keys())[0],
                            "rating": list(r.values())[0]
                        }
                        items.append(item)
                except:
                    item = {
                        'title': row['title'],
                        "team": load[keys[0]],
                        "rating": load[keys[1]]
                        }
                    items.append(item)
            else:
                item = {
                    "title": row['title'],
                    "team": list(load[keys[0]].keys())[0],
                    "rating": load[keys[0]][list(load[keys[0]].keys())[0]]
                }
                items.append(item)
        else:
            item = {
                    "title": row['title'],
                    "team": keys[0],
                    "rating": load[keys[0]]
                }
            items.append(item)

# %%
items
# Out:
# [{'title': 'Bears fire Matt Eberflus following 4-8 start to season; Thomas Brown named interim head coach',
#   'team': 'Chicago Bears',
#   'rating': -3},
#  {'title': "Jaguars' Doug Pederson: Trevor Lawrence (shoulder) expected to play Sunday vs. Texans 'as of right now'",
#   'team': 'Jacksonville Jaguars',
#   'rating': -2},
#  {'title': 'NFL Week 13 bold predictions: T.J. Hockenson posts hat trick; Ladd McConkey and C.J. Stroud ball out',
#   'team': 'T.J. Hockenson',
#   'rating': 1},
#  {'title': 'NFL Week 13 bold predictions: T.J. Hockenson posts hat trick; Ladd McConkey and C.J. Stroud ball out',
#   'team': 'Los Angeles Chargers',
#   'rating': 3},
#  {'title': 'NFL Week 13 bold predictions: T.J. Hockenson posts hat trick; Ladd McConkey and C.J. Stroud ball out',
#   'team': 'Houston Texans',
#   'rating': 4},
#  {'title': 'NFL Week 13 bold predictions: T.J. Hockenson posts hat trick; Ladd McConkey and C.J. Stroud ball out',
#   'team': 'Philadelphia Eagles',
#   'rating': 0},
#  {'title': 'NFL Week 13 bold predictions: T.J. Hockenson posts hat trick; Ladd McConkey and C.J. Stroud ball out',
#   'team': 'Baltimore Ravens',
#   'rating': 0},
#  {'title': 'NFL Week 13 bold predictions: T.J. Hockenson posts hat trick; Ladd McConkey and C.J. Stroud ball out',
#   'team': 'New Orleans Saints',
#   'rating': 2},
#  {'title': 'Giants HC Brian Daboll not concerned with job status despite seventh consecutive loss',
#   'team': 'New York Giants',
#   'rating': -5},
#  {'title': "Cowboys outlast Giants for first home win of season, eye improbable playoff run: 'Why not us?'",
#   'team': 'Dallas Cowboys',
#   'rating': 2},
#  {'title': 'Bears HC Matt Eberflus defends not calling timeout on botched final play of Thanksgiving loss to Lions',
#   'team': 'Chicago Bears',
#   'rating': -3},
#  {'title': "Dolphins won't activate Shaquil Barrett off reserve/retired list",
#   'team': 'Miami Dolphins',
#   'rating': -1},
#  {'title': 'Drew Lock to start for Giants on Thanksgiving Day vs. Cowboys',
#   'team': 'New York Giants',
#   'rating': -4},
#  {'title': 'Chiefs activate Isiah Pacheco (fibula) off injured reserve; RB in line to return on Black Friday vs. Raiders',
#   'team': 'Kansas City Chiefs',
#   'rating': 4},
#  {'title': "Lions' David Montgomery, Amon-Ra St. Brown active for Thanksgiving Day game vs. Bears",
#   'team': 'Detroit Lions',
#   'rating': 4},
#  {'title': 'Fantasy sleepers, Week 13: Favorable matchup for Bryce Young; All aboard the Gus Bus!',
#   'team': 'Tampa Bay Buccaneers',
#   'rating': 3},
#  {'title': "Niners HC Kyle Shanahan: 'Unfair' to expect prime Christian McCaffrey after missing eight weeks",
#   'team': 'San Francisco 49ers',
#   'rating': -2},
#  {'title': "Commanders QB Jayden Daniels on whether he's hitting rookie wall: 'I don't know'",
#   'team': 'Washington Commanders',
#   'rating': -2},
#  {'title': 'Can Dan Campbell, Jared Goff get first Thanksgiving wins, snap seven-game losing streak?',
#   'team': 'Detroit Lions',
#   'rating': 3},
#  {'title': "Neil Reynolds' Week 13 Picks",
#   'team': 'Detroit Lions',
#   'rating': 4},
#  {'title': "Neil Reynolds' Week 13 Picks",
#   'team': 'Dallas Cowboys',
#   'rating': 3},
#  {'title': "Neil Reynolds' Week 13 Picks",
#   'team': 'Miami Dolphins',
#   'rating': 0},
#  {'title': "Neil Reynolds' Week 13 Picks",
#   'team': 'Kansas City Chiefs',
#   'rating': 4},
#  {'title': "Neil Reynolds' Week 13 Picks",
#   'team': 'Los Angeles Chargers',
#   'rating': 1},
#  {'title': "Neil Reynolds' Week 13 Picks",
#   'team': 'Cincinnati Bengals',
#   'rating': 2},
#  {'title': "Neil Reynolds' Week 13 Picks",
#   'team': 'Jacksonville Jaguars',
#   'rating': 1},
#  {'title': "Neil Reynolds' Week 13 Picks",
#   'team': 'Minnesota Vikings',
#   'rating': 4},
#  {'title': "Neil Reynolds' Week 13 Picks",
#   'team': 'Indianapolis Colts',
#   'rating': 2},
#  {'title': "Neil Reynolds' Week 13 Picks",
#   'team': 'Seattle Seahawks',
#   'rating': 1},
#  {'title': "Neil Reynolds' Week 13 Picks",
#   'team': 'Washington Commanders',
#   'rating': 1},
#  {'title': "Neil Reynolds' Week 13 Picks",
#   'team': 'Tampa Bay Buccaneers',
#   'rating': 2},
#  {'title': "Neil Reynolds' Week 13 Picks",
#   'team': 'New Orleans Saints',
#   'rating': 2},
#  {'title': "Neil Reynolds' Week 13 Picks",
#   'team': 'Philadelphia Eagles',
#   'rating': 3},
#  {'title': "Neil Reynolds' Week 13 Picks",
#   'team': 'Buffalo Bills',
#   'rating': 4},
#  {'title': "Neil Reynolds' Week 13 Picks",
#   'team': 'Denver Broncos',
#   'rating': 3},
#  {'title': "Week 13 NFL picks: Can Raiders stun Chiefs on Black Friday? Eagles or Ravens in Sunday's biggest bout?",
#   'team': 'Kansas City Chiefs',
#   'rating': 4},
#  {'title': "Week 13 NFL picks: Can Raiders stun Chiefs on Black Friday? Eagles or Ravens in Sunday's biggest bout?",
#   'team': 'Los Angeles Chargers',
#   'rating': 3},
#  {'title': "Week 13 NFL picks: Can Raiders stun Chiefs on Black Friday? Eagles or Ravens in Sunday's biggest bout?",
#   'team': 'Cincinnati Bengals',
#   'rating': 2},
#  {'title': "Week 13 NFL picks: Can Raiders stun Chiefs on Black Friday? Eagles or Ravens in Sunday's biggest bout?",
#   'team': 'Houston Texans',
#   'rating': -1},
#  {'title': "Week 13 NFL picks: Can Raiders stun Chiefs on Black Friday? Eagles or Ravens in Sunday's biggest bout?",
#   'team': 'Arizona Cardinals',
#   'rating': 2},
#  {'title': "Week 13 NFL picks: Can Raiders stun Chiefs on Black Friday? Eagles or Ravens in Sunday's biggest bout?",
#   'team': 'Indianapolis Colts',
#   'rating': 2},
#  {'title': "Week 13 NFL picks: Can Raiders stun Chiefs on Black Friday? Eagles or Ravens in Sunday's biggest bout?",
#   'team': 'New York Jets',
#   'rating': 1},
#  {'title': "Week 13 NFL picks: Can Raiders stun Chiefs on Black Friday? Eagles or Ravens in Sunday's biggest bout?",
#   'team': 'Washington Commanders',
#   'rating': 0},
#  {'title': "Week 13 NFL picks: Can Raiders stun Chiefs on Black Friday? Eagles or Ravens in Sunday's biggest bout?",
#   'team': 'Tampa Bay Buccaneers',
#   'rating': 3},
#  {'title': "Week 13 NFL picks: Can Raiders stun Chiefs on Black Friday? Eagles or Ravens in Sunday's biggest bout?",
#   'team': 'New Orleans Saints',
#   'rating': 3},
#  {'title': "Week 13 NFL picks: Can Raiders stun Chiefs on Black Friday? Eagles or Ravens in Sunday's biggest bout?",
#   'team': 'Baltimore Ravens',
#   'rating': 2},
#  {'title': "Week 13 NFL picks: Can Raiders stun Chiefs on Black Friday? Eagles or Ravens in Sunday's biggest bout?",
#   'team': 'Buffalo Bills',
#   'rating': 4},
#  {'title': "Week 13 NFL picks: Can Raiders stun Chiefs on Black Friday? Eagles or Ravens in Sunday's biggest bout?",
#   'team': 'Denver Broncos',
#   'rating': 3},
#  {'title': "Week 13 NFL picks: Can Raiders stun Chiefs on Black Friday? Eagles or Ravens in Sunday's biggest bout?",
#   'team': 'Detroit Lions',
#   'rating': 5},
#  {'title': "Week 13 NFL picks: Can Raiders stun Chiefs on Black Friday? Eagles or Ravens in Sunday's biggest bout?",
#   'team': 'Dallas Cowboys',
#   'rating': 2},
#  {'title': "Week 13 NFL picks: Can Raiders stun Chiefs on Black Friday? Eagles or Ravens in Sunday's biggest bout?",
#   'team': 'Green Bay Packers',
#   'rating': 2},
#  {'title': "NFL Fantasy 2024 Start 'Em, Sit 'Em: Defenses for Week 13",
#   'team': 'Washington Commanders',
#   'rating': 3},
#  {'title': "Sophomore slump/bump/breakout: What's up with C.J. Stroud? Bryce Young reborn? Next great slot?",
#   'team': 'Houston Texans',
#   'rating': -2},
#  {'title': "Raiders-Chiefs on Black Friday: What We Learned from Kansas City's win over Las Vegas",
#   'team': 'None',
#   'rating': 0},
#  {'title': 'Chiefs become first team to clinch 2024 playoff berth with win over Raiders; guarantee shot at three-peat',
#   'team': 'Kansas City Chiefs',
#   'rating': 5},
#  {'title': 'Niners QB Brock Purdy (shoulder) questionable to play vs. Bills',
#   'team': 'San Francisco 49ers',
#   'rating': -1},
#  {'title': 'NFL fantasy 2024 higher or lower: Who will out/underperform projections in Week 13?',
#   'team': 'None',
#   'rating': 0},
#  {'title': "Sam Darnold, Chase Young among 2025 free agents who can cash in down the stretch of '24 NFL season",
#   'team': 'Minnesota Vikings',
#   'rating': 4}]

# %%
pd.DataFrame(items)
# Out:
#                                                 title                   team  \
# 0   Bears fire Matt Eberflus following 4-8 start t...          Chicago Bears
# 1   Jaguars' Doug Pederson: Trevor Lawrence (shoul...   Jacksonville Jaguars
# 2   NFL Week 13 bold predictions: T.J. Hockenson p...         T.J. Hockenson
# 3   NFL Week 13 bold predictions: T.J. Hockenson p...   Los Angeles Chargers
# 4   NFL Week 13 bold predictions: T.J. Hockenson p...         Houston Texans
# 5   NFL Week 13 bold predictions: T.J. Hockenson p...    Philadelphia Eagles
# 6   NFL Week 13 bold predictions: T.J. Hockenson p...       Baltimore Ravens
# 7   NFL Week 13 bold predictions: T.J. Hockenson p...     New Orleans Saints
# 8   Giants HC Brian Daboll not concerned with job ...        New York Giants
# 9   Cowboys outlast Giants for first home win of s...         Dallas Cowboys
# 10  Bears HC Matt Eberflus defends not calling tim...          Chicago Bears
# 11  Dolphins won't activate Shaquil Barrett off re...         Miami Dolphins
# 12  Drew Lock to start for Giants on Thanksgiving ...        New York Giants
# 13  Chiefs activate Isiah Pacheco (fibula) off inj...     Kansas City Chiefs
# 14  Lions' David Montgomery, Amon-Ra St. Brown act...          Detroit Lions
# 15  Fantasy sleepers, Week 13: Favorable matchup f...   Tampa Bay Buccaneers
# 16  Niners HC Kyle Shanahan: 'Unfair' to expect pr...    San Francisco 49ers
# 17  Commanders QB Jayden Daniels on whether he's h...  Washington Commanders
# 18  Can Dan Campbell, Jared Goff get first Thanksg...          Detroit Lions
# 19                       Neil Reynolds' Week 13 Picks          Detroit Lions
# 20                       Neil Reynolds' Week 13 Picks         Dallas Cowboys
# 21                       Neil Reynolds' Week 13 Picks         Miami Dolphins
# 22                       Neil Reynolds' Week 13 Picks     Kansas City Chiefs
# 23                       Neil Reynolds' Week 13 Picks   Los Angeles Chargers
# 24                       Neil Reynolds' Week 13 Picks     Cincinnati Bengals
# 25                       Neil Reynolds' Week 13 Picks   Jacksonville Jaguars
# 26                       Neil Reynolds' Week 13 Picks      Minnesota Vikings
# 27                       Neil Reynolds' Week 13 Picks     Indianapolis Colts
# 28                       Neil Reynolds' Week 13 Picks       Seattle Seahawks
# 29                       Neil Reynolds' Week 13 Picks  Washington Commanders
# 30                       Neil Reynolds' Week 13 Picks   Tampa Bay Buccaneers
# 31                       Neil Reynolds' Week 13 Picks     New Orleans Saints
# 32                       Neil Reynolds' Week 13 Picks    Philadelphia Eagles
# 33                       Neil Reynolds' Week 13 Picks          Buffalo Bills
# 34                       Neil Reynolds' Week 13 Picks         Denver Broncos
# 35  Week 13 NFL picks: Can Raiders stun Chiefs on ...     Kansas City Chiefs
# 36  Week 13 NFL picks: Can Raiders stun Chiefs on ...   Los Angeles Chargers
# 37  Week 13 NFL picks: Can Raiders stun Chiefs on ...     Cincinnati Bengals
# 38  Week 13 NFL picks: Can Raiders stun Chiefs on ...         Houston Texans
# 39  Week 13 NFL picks: Can Raiders stun Chiefs on ...      Arizona Cardinals
# 40  Week 13 NFL picks: Can Raiders stun Chiefs on ...     Indianapolis Colts
# 41  Week 13 NFL picks: Can Raiders stun Chiefs on ...          New York Jets
# 42  Week 13 NFL picks: Can Raiders stun Chiefs on ...  Washington Commanders
# 43  Week 13 NFL picks: Can Raiders stun Chiefs on ...   Tampa Bay Buccaneers
# 44  Week 13 NFL picks: Can Raiders stun Chiefs on ...     New Orleans Saints
# 45  Week 13 NFL picks: Can Raiders stun Chiefs on ...       Baltimore Ravens
# 46  Week 13 NFL picks: Can Raiders stun Chiefs on ...          Buffalo Bills
# 47  Week 13 NFL picks: Can Raiders stun Chiefs on ...         Denver Broncos
# 48  Week 13 NFL picks: Can Raiders stun Chiefs on ...          Detroit Lions
# 49  Week 13 NFL picks: Can Raiders stun Chiefs on ...         Dallas Cowboys
# 50  Week 13 NFL picks: Can Raiders stun Chiefs on ...      Green Bay Packers
# 51  NFL Fantasy 2024 Start 'Em, Sit 'Em: Defenses ...  Washington Commanders
# 52  Sophomore slump/bump/breakout: What's up with ...         Houston Texans
# 53  Raiders-Chiefs on Black Friday: What We Learne...                   None
# 54  Chiefs become first team to clinch 2024 playof...     Kansas City Chiefs
# 55  Niners QB Brock Purdy (shoulder) questionable ...    San Francisco 49ers
# 56  NFL fantasy 2024 higher or lower: Who will out...                   None
# 57  Sam Darnold, Chase Young among 2025 free agent...      Minnesota Vikings
#
#     rating
# 0       -3
# 1       -2
# 2        1
# 3        3
# 4        4
# 5        0
# 6        0
# 7        2
# 8       -5
# 9        2
# 10      -3
# 11      -1
# 12      -4
# 13       4
# 14       4
# 15       3
# 16      -2
# 17      -2
# 18       3
# 19       4
# 20       3
# 21       0
# 22       4
# 23       1
# 24       2
# 25       1
# 26       4
# 27       2
# 28       1
# 29       1
# 30       2
# 31       2
# 32       3
# 33       4
# 34       3
# 35       4
# 36       3
# 37       2
# 38      -1
# 39       2
# 40       2
# 41       1
# 42       0
# 43       3
# 44       3
# 45       2
# 46       4
# 47       3
# 48       5
# 49       2
# 50       2
# 51       3
# 52      -2
# 53       0
# 54       5
# 55      -1
# 56       0
# 57       4

# %%
keys
# Out:
# ['team_name', 'rating']

# %%
df
# Out:
#                                                 title          date  \
# 1   Bears fire Matt Eberflus following 4-8 start t...  Nov 29, 2024
# 3   Jaguars' Doug Pederson: Trevor Lawrence (shoul...  Nov 29, 2024
# 5   NFL Week 13 bold predictions: T.J. Hockenson p...  Nov 29, 2024
# 8   Giants HC Brian Daboll not concerned with job ...  Nov 29, 2024
# 10  Cowboys outlast Giants for first home win of s...  Nov 28, 2024
# 12  Bears HC Matt Eberflus defends not calling tim...  Nov 28, 2024
# 14  Dolphins won't activate Shaquil Barrett off re...  Nov 28, 2024
# 15  Drew Lock to start for Giants on Thanksgiving ...  Nov 28, 2024
# 16  Chiefs activate Isiah Pacheco (fibula) off inj...  Nov 28, 2024
# 18  Lions' David Montgomery, Amon-Ra St. Brown act...  Nov 28, 2024
# 19  Week 13 Thursday inactives: Thanksgiving tripl...  Nov 28, 2024
# 21  Fantasy sleepers, Week 13: Favorable matchup f...  Nov 28, 2024
# 22  Niners HC Kyle Shanahan: 'Unfair' to expect pr...  Nov 28, 2024
# 24  Commanders QB Jayden Daniels on whether he's h...  Nov 28, 2024
# 25  Can Dan Campbell, Jared Goff get first Thanksg...  Nov 28, 2024
# 26                       Neil Reynolds' Week 13 Picks  Nov 28, 2024
# 27  Week 13 NFL picks: Can Raiders stun Chiefs on ...  Nov 27, 2024
# 30  NFL Fantasy 2024 Start 'Em, Sit 'Em: Defenses ...  Nov 27, 2024
# 32  Sophomore slump/bump/breakout: What's up with ...  Nov 29, 2024
# 33  Raiders-Chiefs on Black Friday: What We Learne...  Nov 29, 2024
# 34  Chiefs become first team to clinch 2024 playof...  Nov 29, 2024
# 35  Niners QB Brock Purdy (shoulder) questionable ...  Nov 29, 2024
# 36  NFL fantasy 2024 higher or lower: Who will out...  Nov 29, 2024
# 37  Sam Darnold, Chase Young among 2025 free agent...  Nov 29, 2024
#
#                                                  link  \
# 1   https://www.nfl.com/news/bears-firing-head-coa...
# 3   https://www.nfl.com/news/jaguars-doug-pederson...
# 5   https://www.nfl.com/news/nfl-week-13-bold-pred...
# 8   https://www.nfl.com/news/brian-daboll-not-conc...
# 10  https://www.nfl.com/news/cowboys-outlast-giant...
# 12  https://www.nfl.com/news/bears-matt-eberflus-c...
# 14  https://www.nfl.com/news/dolphins-won-t-activa...
# 15  https://www.nfl.com/news/drew-lock-to-start-fo...
# 16  https://www.nfl.com/news/chiefs-activate-isiah...
# 18  https://www.nfl.com/news/lions-david-montgomer...
# 19  https://www.nfl.com/news/week-13-2024-thursday...
# 21  https://www.nfl.com/news/fantasy-football-slee...
# 22  https://www.nfl.com/news/niners-hc-kyle-shanah...
# 24  https://www.nfl.com/news/commanders-qb-jayden-...
# 25  https://www.nfl.com/news/can-dan-campbell-jare...
# 26  https://www.nfl.com/news/neil-reynolds-week-13...
# 27  https://www.nfl.com/news/week-13-nfl-picks-202...
# 30  https://www.nfl.com/news/nfl-fantasy-2024-star...
# 32  https://www.nfl.com/news/sophomore-slump-bump-...
# 33  https://www.nfl.com/news/raiders-chiefs-on-bla...
# 34  https://www.nfl.com/news/chiefs-become-first-t...
# 35  https://www.nfl.com/news/niners-qb-brock-purdy...
# 36  https://www.nfl.com/news/nfl-fantasy-2024-high...
# 37  https://www.nfl.com/news/sam-darnold-chase-you...
#
#                                             image_url relevant  \
# 1   ......     True
# 3   ......     True
# 5   ......     True
# 8   ......     True
# 10  ......     True
# 12  ......     True
# 14  ......     True
# 15  ......     True
# 16  ......     True
# 18  ......     True
# 19  ......     True
# 21  ......     True
# 22  ......     True
# 24  ......     True
# 25  ......     True
# 26  ......     True
# 27  ......     True
# 30  ......     True
# 32  https://static.www.nfl.com/image/upload/t_edit...     True
# 33  https://static.www.nfl.com/image/upload/t_edit...     True
# 34  https://static.www.nfl.com/image/upload/t_edit...     True
# 35  https://static.www.nfl.com/image/upload/t_edit...     True
# 36  ......     True
# 37  ......     True
#
#                                              ai_score
# 1                                                 ...
# 3                        {"Jacksonville Jaguars": -2}
# 5   {  "results": [    {"T.J. Hockenson": 1},    {...
# 8                             {"New York Giants": -5}
# 10                              {"Dallas Cowboys": 2}
# 12  {    "team": {        "Chicago Bears": -3    }  }
# 14                           { "Miami Dolphins": -1 }
# 15                            {"New York Giants": -4}
# 16                        \t{"Kansas City Chiefs": 4}
# 18                               {"Detroit Lions": 4}
# 19                                                 {}
# 21                        {"Tampa Bay Buccaneers": 3}
# 22                        {"San Francisco 49ers": -2}
# 24                      {"Washington Commanders": -2}
# 25                               {"Detroit Lions": 3}
# 26  { "result": [  {"Detroit Lions": 4},  {"Dallas...
# 27  {  "results": [    {"Kansas City Chiefs": 4}, ...
# 30  { "team_name": "Washington Commanders", "ratin...
# 32        {        "Houston Texans": -2    }
# 33                                        {"None": 0}
# 34                          {"Kansas City Chiefs": 5}
# 35                        {"San Francisco 49ers": -1}
# 36                     { "Team": "None", "Score": 0 }
# 37                         { "Minnesota Vikings": 4 }

# %%
for r in load[keys[0]]:
    print(list(r.keys())[0])
# Out:
# T.J. Hockenson
# Los Angeles Chargers
# Houston Texans
# Philadelphia Eagles
# Baltimore Ravens
# New Orleans Saints

# %%
len(keys)
# Out:
# 0

# %%
json.loads('{"Jacksonville Jaguars": -2}').keys()
# Out:
# dict_keys(['Jacksonville Jaguars'])

# %%
df
# Out:
#                                                 title       date  \
# 1   Bears fire Matt Eberflus following 4-8 start t... 2024-11-29
# 3   Jaguars' Doug Pederson: Trevor Lawrence (shoul... 2024-11-29
# 5   NFL Week 13 bold predictions: T.J. Hockenson p... 2024-11-29
# 8   Giants HC Brian Daboll not concerned with job ... 2024-11-29
# 10  Cowboys outlast Giants for first home win of s... 2024-11-28
# 12  Bears HC Matt Eberflus defends not calling tim... 2024-11-28
# 14  Dolphins won't activate Shaquil Barrett off re... 2024-11-28
# 15  Drew Lock to start for Giants on Thanksgiving ... 2024-11-28
# 16  Chiefs activate Isiah Pacheco (fibula) off inj... 2024-11-28
# 18  Lions' David Montgomery, Amon-Ra St. Brown act... 2024-11-28
# 19  Week 13 Thursday inactives: Thanksgiving tripl... 2024-11-28
# 21  Fantasy sleepers, Week 13: Favorable matchup f... 2024-11-28
# 22  Niners HC Kyle Shanahan: 'Unfair' to expect pr... 2024-11-28
# 24  Commanders QB Jayden Daniels on whether he's h... 2024-11-28
# 25  Can Dan Campbell, Jared Goff get first Thanksg... 2024-11-28
# 26                       Neil Reynolds' Week 13 Picks 2024-11-28
# 27  Week 13 NFL picks: Can Raiders stun Chiefs on ... 2024-11-27
# 30  NFL Fantasy 2024 Start 'Em, Sit 'Em: Defenses ... 2024-11-27
# 32  Sophomore slump/bump/breakout: What's up with ... 2024-11-29
# 33  Raiders-Chiefs on Black Friday: What We Learne... 2024-11-29
# 34  Chiefs become first team to clinch 2024 playof... 2024-11-29
# 35  Niners QB Brock Purdy (shoulder) questionable ... 2024-11-29
# 36  NFL fantasy 2024 higher or lower: Who will out... 2024-11-29
# 37  Sam Darnold, Chase Young among 2025 free agent... 2024-11-29
#
#                                                  link  \
# 1   https://www.nfl.com/news/bears-firing-head-coa...
# 3   https://www.nfl.com/news/jaguars-doug-pederson...
# 5   https://www.nfl.com/news/nfl-week-13-bold-pred...
# 8   https://www.nfl.com/news/brian-daboll-not-conc...
# 10  https://www.nfl.com/news/cowboys-outlast-giant...
# 12  https://www.nfl.com/news/bears-matt-eberflus-c...
# 14  https://www.nfl.com/news/dolphins-won-t-activa...
# 15  https://www.nfl.com/news/drew-lock-to-start-fo...
# 16  https://www.nfl.com/news/chiefs-activate-isiah...
# 18  https://www.nfl.com/news/lions-david-montgomer...
# 19  https://www.nfl.com/news/week-13-2024-thursday...
# 21  https://www.nfl.com/news/fantasy-football-slee...
# 22  https://www.nfl.com/news/niners-hc-kyle-shanah...
# 24  https://www.nfl.com/news/commanders-qb-jayden-...
# 25  https://www.nfl.com/news/can-dan-campbell-jare...
# 26  https://www.nfl.com/news/neil-reynolds-week-13...
# 27  https://www.nfl.com/news/week-13-nfl-picks-202...
# 30  https://www.nfl.com/news/nfl-fantasy-2024-star...
# 32  https://www.nfl.com/news/sophomore-slump-bump-...
# 33  https://www.nfl.com/news/raiders-chiefs-on-bla...
# 34  https://www.nfl.com/news/chiefs-become-first-t...
# 35  https://www.nfl.com/news/niners-qb-brock-purdy...
# 36  https://www.nfl.com/news/nfl-fantasy-2024-high...
# 37  https://www.nfl.com/news/sam-darnold-chase-you...
#
#                                             image_url relevant  \
# 1   ......     True
# 3   ......     True
# 5   ......     True
# 8   ......     True
# 10  ......     True
# 12  ......     True
# 14  ......     True
# 15  ......     True
# 16  ......     True
# 18  ......     True
# 19  ......     True
# 21  ......     True
# 22  ......     True
# 24  ......     True
# 25  ......     True
# 26  ......     True
# 27  ......     True
# 30  ......     True
# 32  https://static.www.nfl.com/image/upload/t_edit...     True
# 33  https://static.www.nfl.com/image/upload/t_edit...     True
# 34  https://static.www.nfl.com/image/upload/t_edit...     True
# 35  https://static.www.nfl.com/image/upload/t_edit...     True
# 36  ......     True
# 37  ......     True
#
#                                              ai_score
# 1                                                 ...
# 3                        {"Jacksonville Jaguars": -2}
# 5   {  "results": [    {"T.J. Hockenson": 1},    {...
# 8                             {"New York Giants": -5}
# 10                              {"Dallas Cowboys": 2}
# 12  {    "team": {        "Chicago Bears": -3    }  }
# 14                           { "Miami Dolphins": -1 }
# 15                            {"New York Giants": -4}
# 16                        \t{"Kansas City Chiefs": 4}
# 18                               {"Detroit Lions": 4}
# 19                                                 {}
# 21                        {"Tampa Bay Buccaneers": 3}
# 22                        {"San Francisco 49ers": -2}
# 24                      {"Washington Commanders": -2}
# 25                               {"Detroit Lions": 3}
# 26  { "result": [  {"Detroit Lions": 4},  {"Dallas...
# 27  {  "results": [    {"Kansas City Chiefs": 4}, ...
# 30  { "team_name": "Washington Commanders", "ratin...
# 32        {        "Houston Texans": -2    }
# 33                                        {"None": 0}
# 34                          {"Kansas City Chiefs": 5}
# 35                        {"San Francisco 49ers": -1}
# 36                     { "Team": "None", "Score": 0 }
# 37                         { "Minnesota Vikings": 4 }

# %%
for ix, row in df.iterrows():
    ai_score = json.loads(row['ai_score'].strip().replace('\n', ''))
    df_keys = list(ai_score.keys())
    #df.at[ix, 'ai_score'] = 
    if df_keys:
        if 'result' in ai_score or 'results' in ai_score:
            for game in ai_score[df_keys[0]]:
                final_results.append(game)
        else:
            final_results.append(row['ai_score'])

def cast_int_or_zero(value):
    try:
        return(int(value))
    except:
        return None
    
df = pd.DataFrame(final_results)
df[0] = df[0].apply(lambda x: x.replace('\n', '').strip() if type(x) == str else x)
df['json'] = df[0].apply(lambda x: json.dumps(x))

# %%
df[0]
# Out:
# 0                               {  "Chicago Bears": -3}
# 1                          {"Jacksonville Jaguars": -2}
# 2                                 {'T.J. Hockenson': 1}
# 3                           {'Los Angeles Chargers': 3}
# 4                                 {'Houston Texans': 4}
# 5                            {'Philadelphia Eagles': 0}
# 6                               {'Baltimore Ravens': 0}
# 7                             {'New Orleans Saints': 2}
# 8                               {"New York Giants": -5}
# 9                                 {"Dallas Cowboys": 2}
# 10    {    "team": {        "Chicago Bears": -3    }  }
# 11                             { "Miami Dolphins": -1 }
# 12                              {"New York Giants": -4}
# 13                            {"Kansas City Chiefs": 4}
# 14                                 {"Detroit Lions": 4}
# 15                          {"Tampa Bay Buccaneers": 3}
# 16                          {"San Francisco 49ers": -2}
# 17                        {"Washington Commanders": -2}
# 18                                 {"Detroit Lions": 3}
# 19                                 {'Detroit Lions': 4}
# 20                                {'Dallas Cowboys': 3}
# 21                                {'Miami Dolphins': 0}
# 22                            {'Kansas City Chiefs': 4}
# 23                          {'Los Angeles Chargers': 1}
# 24                            {'Cincinnati Bengals': 2}
# 25                          {'Jacksonville Jaguars': 1}
# 26                             {'Minnesota Vikings': 4}
# 27                            {'Indianapolis Colts': 2}
# 28                              {'Seattle Seahawks': 1}
# 29                         {'Washington Commanders': 1}
# 30                          {'Tampa Bay Buccaneers': 2}
# 31                            {'New Orleans Saints': 2}
# 32                           {'Philadelphia Eagles': 3}
# 33                                 {'Buffalo Bills': 4}
# 34                                {'Denver Broncos': 3}
# 35                            {'Kansas City Chiefs': 4}
# 36                          {'Los Angeles Chargers': 3}
# 37                            {'Cincinnati Bengals': 2}
# 38                               {'Houston Texans': -1}
# 39                             {'Arizona Cardinals': 2}
# 40                            {'Indianapolis Colts': 2}
# 41                                 {'New York Jets': 1}
# 42                         {'Washington Commanders': 0}
# 43                          {'Tampa Bay Buccaneers': 3}
# 44                            {'New Orleans Saints': 3}
# 45                              {'Baltimore Ravens': 2}
# 46                                 {'Buffalo Bills': 4}
# 47                                {'Denver Broncos': 3}
# 48                                 {'Detroit Lions': 5}
# 49                                {'Dallas Cowboys': 2}
# 50                             {'Green Bay Packers': 2}
# 51    { "team_name": "Washington Commanders", "ratin...
# 52                   {        "Houston Texans": -2    }
# 53                                          {"None": 0}
# 54                            {"Kansas City Chiefs": 5}
# 55                          {"San Francisco 49ers": -1}
# 56                       { "Team": "None", "Score": 0 }
# 57                           { "Minnesota Vikings": 4 }
# Name: 0, dtype: object

# %%
# Function to parse JSON-like strings
def parse_json_like_string(s):
    try:
        # Replace single quotes with double quotes
        s = s.replace("'", '"')
        # Remove leading and trailing spaces
        s = s.strip()
        # Parse the JSON string
        return json.loads(s)
    except json.JSONDecodeError:
        return None

# Parse the JSON-like strings
df['parsed'] = df[0].apply(parse_json_like_string)

# Normalize the parsed data
normalized_df = pd.json_normalize(df['parsed'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 14
#      11         return None
#      13 # Parse the JSON-like strings
# ---> 14 df['parsed'] = df[0].apply(parse_json_like_string)
#      16 # Normalize the parsed data
#      17 normalized_df = pd.json_normalize(df['parsed'])
#
# File c:\Users\adams\anaconda3\envs\nfl-docker\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\adams\anaconda3\envs\nfl-docker\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\adams\anaconda3\envs\nfl-docker\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\adams\anaconda3\envs\nfl-docker\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\adams\anaconda3\envs\nfl-docker\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[72], line 5, in parse_json_like_string(s)
#       2 def parse_json_like_string(s):
#       3     try:
#       4         # Replace single quotes with double quotes
# ----> 5         s = s.replace("'", '"')
#       6         # Remove leading and trailing spaces
#       7         s = s.strip()
#
# AttributeError: 'dict' object has no attribute 'replace'

# %%
for i, x in df.iterrows():
    try:
        cleaned = json.loads(x[0].replace(' ', ''))
    except:
        print("didnt work")
        cleaned = x[0]
        break
    print(cleaned)#.keys()
    #print(cleaned).values()
# Out:
# {'ChicagoBears': -3}
# {'JacksonvilleJaguars': -2}
# didnt work

# %%
cleaned.keys()
# Out:
# dict_keys(['T.J. Hockenson'])

# %%
# Melt the DataFrame to long format
df_melted = df.melt(var_name='TEAM')
# Drop rows with NaN values in the Score column
df_melted['value'] = df_melted['value'].apply(lambda x: cast_int_or_zero(x))
df_melted = df_melted.dropna(subset=['value'])

# Group by TEAM and calculate AVG and SUM
df_grouped = df_melted.groupby('TEAM')['value'].agg(['mean', 'sum']).reset_index()

# Rename columns
df_grouped.columns = ['TEAM', 'AVG', 'SUM']

teams = ['Arizona Cardinals',
'Baltimore Ravens',
'Buffalo Bills',
'Chicago Bears',
'Cincinnati Bengals',
'Dallas Cowboys',
'Denver Broncos',
'Detroit Lions',
'Green Bay Packers',
'Houston Texans',
'Indianapolis Colts',
'Jacksonville Jaguars',
'Kansas City Chiefs',
'Los Angeles Chargers',
'Miami Dolphins',
'Minnesota Vikings',
'New Orleans Saints',
'New York Giants',
'New York Jets',
'Philadelphia Eagles',
'San Francisco 49ers',
'Seattle Seahawks',
'Tampa Bay Buccaneers',
'Washington Commanders',]

# %%
df_grouped[df_grouped['TEAM'].isin(teams)]
# Out:
# Empty DataFrame
# Columns: [TEAM, AVG, SUM]
# Index: []
